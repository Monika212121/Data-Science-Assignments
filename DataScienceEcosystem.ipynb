# %% [markdown]
# # 2. Data Science Tools and Ecosystem

# %% [markdown]
# # 3. In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # 4. Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# # 5.
#
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# # 6.
#
# | Data Science Tools |
# |--------------------|
# | Jupyter Notebook   |
# | RStudio            |
# | VS Code            |

# %% [markdown]
# # 7.
#
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# 8. This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# 9. # This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# # 10.
#
# **Objectives:**
#
# - List popular languages for Data Science
# - List commonly used data science libraries
# - Create a Data Science tools table
# - Practice basic arithmetic expressions in Python
# - Convert minutes into hours using Python code

# %% [markdown]
# # 10.
#
# ## Author
# Monika Gadewar
